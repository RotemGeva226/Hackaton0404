# %%
#pip install matplotlib

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import time
# imports
import pandas as pd
import os
from sklearn.preprocessing import LabelEncoder

# %%
# Use raw string (r"") or double backslashes to avoid path issues


# Read the CSV file
df = pd.read_csv("ED_full_data(in).csv")

# %%
processed = df.copy()
processed['timestamp'] = pd.to_datetime(df['timestamp'], utc=True, format='mixed')
processed['clean_timestamp'] = processed['timestamp'].dt.strftime('%Y-%m-%d %H:%M:%S') #Without utc and microseconds

# %%
processed = df.copy()
processed['timestamp'] = pd.to_datetime(df['timestamp'], utc=True, format='mixed')
processed['clean_timestamp'] = processed['timestamp'].dt.strftime('%Y-%m-%d %H:%M:%S') #Without utc and microseconds

# %%
print(processed['clean_timestamp'].head())
print(processed['clean_timestamp'].tail())
# Out:
# 0    2023-11-08 08:12:03
# 1    2023-11-08 08:12:03
# 2    2024-03-18 10:08:57
# 3    2024-03-18 10:08:58
# 4    2024-03-18 13:54:53
# Name: clean_timestamp, dtype: object
# 463892    2025-01-23 10:07:21
# 463893    2025-01-23 10:10:50
# 463894    2025-01-23 10:14:00
# 463895    2025-01-23 10:14:00
# 463896    2025-01-23 10:14:01
# Name: clean_timestamp, dtype: object

# %%
# Create date and time columns
processed['clean_timestamp'] = pd.to_datetime(processed['clean_timestamp'])
processed['date'] = processed['clean_timestamp'].dt.date
processed['time'] = processed['clean_timestamp'].dt.time
print(processed['time'].head())
print(processed['date'].head())
# Out:
# 0    08:12:03
# 1    08:12:03
# 2    10:08:57
# 3    10:08:58
# 4    13:54:53
# Name: time, dtype: object
# 0    2023-11-08
# 1    2023-11-08
# 2    2024-03-18
# 3    2024-03-18
# 4    2024-03-18
# Name: date, dtype: object

# %%
# Remove old columns
processed = processed.drop(columns=['clean_timestamp', 'timestamp'], axis=1)

# %%
processed
# Out:
#                      department            room    requirement     status  \
# 0       מיון כירורגיה - מ.הלכים         חדר הלם     רמת דחיפות          4
# 1                    מיון פנימי  מיון קורונה ב`     רמת דחיפות          3
# 2                             A            A104   ניקיון تنظيف  satisfied
# 3                             A            A104   ניקיון تنظيف   required
# 4                    טראומה חדש              T5  כח עזר - אוכל  satisfied
# ...                         ...             ...            ...        ...
# 463892                        A            A114     בדיקת רופא  satisfied
# 463893                        C            C316     בדיקת רופא  satisfied
# 463894                        A            A104       בדיקת דם   required
# 463895                        A            A104           תפוס   required
# 463896                        A            A104     בדיקת רופא   required
#
#               date      time
# 0       2023-11-08  08:12:03
# 1       2023-11-08  08:12:03
# 2       2024-03-18  10:08:57
# 3       2024-03-18  10:08:58
# 4       2024-03-18  13:54:53
# ...            ...       ...
# 463892  2025-01-23  10:07:21
# 463893  2025-01-23  10:10:50
# 463894  2025-01-23  10:14:00
# 463895  2025-01-23  10:14:00
# 463896  2025-01-23  10:14:01
#
# [463897 rows x 6 columns]

# %%
# Convert to datetime
processed['date'] = pd.to_datetime(processed['date'])

# %%
processed
# Out:
#                      department            room    requirement     status  \
# 0       מיון כירורגיה - מ.הלכים         חדר הלם     רמת דחיפות          4
# 1                    מיון פנימי  מיון קורונה ב`     רמת דחיפות          3
# 2                             A            A104   ניקיון تنظيف  satisfied
# 3                             A            A104   ניקיון تنظيف   required
# 4                    טראומה חדש              T5  כח עזר - אוכל  satisfied
# ...                         ...             ...            ...        ...
# 463892                        A            A114     בדיקת רופא  satisfied
# 463893                        C            C316     בדיקת רופא  satisfied
# 463894                        A            A104       בדיקת דם   required
# 463895                        A            A104           תפוס   required
# 463896                        A            A104     בדיקת רופא   required
#
#              date      time
# 0      2023-11-08  08:12:03
# 1      2023-11-08  08:12:03
# 2      2024-03-18  10:08:57
# 3      2024-03-18  10:08:58
# 4      2024-03-18  13:54:53
# ...           ...       ...
# 463892 2025-01-23  10:07:21
# 463893 2025-01-23  10:10:50
# 463894 2025-01-23  10:14:00
# 463895 2025-01-23  10:14:00
# 463896 2025-01-23  10:14:01
#
# [463897 rows x 6 columns]

# %%
# Extract year, month, day
processed['day'] = processed['date'].dt.day
processed['month'] = processed['date'].dt.month
processed['year'] = processed['date'].dt.year

# %%
processed
# Out:
#                      department            room    requirement     status  \
# 0       מיון כירורגיה - מ.הלכים         חדר הלם     רמת דחיפות          4
# 1                    מיון פנימי  מיון קורונה ב`     רמת דחיפות          3
# 2                             A            A104   ניקיון تنظيف  satisfied
# 3                             A            A104   ניקיון تنظيف   required
# 4                    טראומה חדש              T5  כח עזר - אוכל  satisfied
# ...                         ...             ...            ...        ...
# 463892                        A            A114     בדיקת רופא  satisfied
# 463893                        C            C316     בדיקת רופא  satisfied
# 463894                        A            A104       בדיקת דם   required
# 463895                        A            A104           תפוס   required
# 463896                        A            A104     בדיקת רופא   required
#
#              date      time  day  month  year
# 0      2023-11-08  08:12:03    8     11  2023
# 1      2023-11-08  08:12:03    8     11  2023
# 2      2024-03-18  10:08:57   18      3  2024
# 3      2024-03-18  10:08:58   18      3  2024
# 4      2024-03-18  13:54:53   18      3  2024
# ...           ...       ...  ...    ...   ...
# 463892 2025-01-23  10:07:21   23      1  2025
# 463893 2025-01-23  10:10:50   23      1  2025
# 463894 2025-01-23  10:14:00   23      1  2025
# 463895 2025-01-23  10:14:00   23      1  2025
# 463896 2025-01-23  10:14:01   23      1  2025
#
# [463897 rows x 9 columns]

# %%
# Extract hour, minute and seconds
processed['time'] = pd.to_datetime(processed['time'], format='%H:%M:%S').dt.time
processed['hours'] =  processed['time'].apply(lambda x: x.hour)
processed['minutes'] = processed['time'].apply(lambda x: x.minute)
processed['seconds'] = processed['time'].apply(lambda x: x.second)

# %%
processed
# Out:
#                      department            room    requirement     status  \
# 0       מיון כירורגיה - מ.הלכים         חדר הלם     רמת דחיפות          4
# 1                    מיון פנימי  מיון קורונה ב`     רמת דחיפות          3
# 2                             A            A104   ניקיון تنظيف  satisfied
# 3                             A            A104   ניקיון تنظيف   required
# 4                    טראומה חדש              T5  כח עזר - אוכל  satisfied
# ...                         ...             ...            ...        ...
# 463892                        A            A114     בדיקת רופא  satisfied
# 463893                        C            C316     בדיקת רופא  satisfied
# 463894                        A            A104       בדיקת דם   required
# 463895                        A            A104           תפוס   required
# 463896                        A            A104     בדיקת רופא   required
#
#              date      time  day  month  year  hours  minutes  seconds
# 0      2023-11-08  08:12:03    8     11  2023      8       12        3
# 1      2023-11-08  08:12:03    8     11  2023      8       12        3
# 2      2024-03-18  10:08:57   18      3  2024     10        8       57
# 3      2024-03-18  10:08:58   18      3  2024     10        8       58
# 4      2024-03-18  13:54:53   18      3  2024     13       54       53
# ...           ...       ...  ...    ...   ...    ...      ...      ...
# 463892 2025-01-23  10:07:21   23      1  2025     10        7       21
# 463893 2025-01-23  10:10:50   23      1  2025     10       10       50
# 463894 2025-01-23  10:14:00   23      1  2025     10       14        0
# 463895 2025-01-23  10:14:00   23      1  2025     10       14        0
# 463896 2025-01-23  10:14:01   23      1  2025     10       14        1
#
# [463897 rows x 12 columns]

# %%
processed['requirement'].unique()
# Out:
# array(['רמת דחיפות', 'ניקיון تنظيف', 'כח עזר - אוכל', 'כח עזר - שונות',
#        'צר"פ', 'כביסה', 'כח עזר - סיוע למטופל', 'תפוס', 'בדיקת דם',
#        'בדיקת אק"ג', 'יעוץ', 'נקיון - החלפת פרגוד', 'נקיון - בידוד',
#        'בדיקת רופא'], dtype=object)

# %%
# Label Encoding
encoder = LabelEncoder()
processed['requirements_category'] = encoder.fit_transform(processed['requirement'])

# %%
# Label mapping
category_mapping = dict(zip(encoder.classes_, encoder.transform(encoder.classes_)))
print("\nCategory to Label Mapping:")
print(category_mapping)
# Out:
# Category to Label Mapping:
# {'בדיקת אק"ג': np.int64(0), 'בדיקת דם': np.int64(1), 'בדיקת רופא': np.int64(2), 'יעוץ': np.int64(3), 'כביסה': np.int64(4), 'כח עזר - אוכל': np.int64(5), 'כח עזר - סיוע למטופל': np.int64(6), 'כח עזר - שונות': np.int64(7), 'ניקיון تنظيف': np.int64(8), 'נקיון - בידוד': np.int64(9), 'נקיון - החלפת פרגוד': np.int64(10), 'צר"פ': np.int64(11), 'רמת דחיפות': np.int64(12), 'תפוס': np.int64(13)}

# %%
# Move new column next to requirements column
cols = list(processed.columns)
cols.remove('requirements_category')  # Remove column 'C'
cols.insert(3, 'requirements_category')  # Insert column 'C' after 'A'
processed = processed[cols]
processed
# Out:
#                      department            room    requirement  \
# 0       מיון כירורגיה - מ.הלכים         חדר הלם     רמת דחיפות
# 1                    מיון פנימי  מיון קורונה ב`     רמת דחיפות
# 2                             A            A104   ניקיון تنظيف
# 3                             A            A104   ניקיון تنظيف
# 4                    טראומה חדש              T5  כח עזר - אוכל
# ...                         ...             ...            ...
# 463892                        A            A114     בדיקת רופא
# 463893                        C            C316     בדיקת רופא
# 463894                        A            A104       בדיקת דם
# 463895                        A            A104           תפוס
# 463896                        A            A104     בדיקת רופא
#
#         requirements_category     status       date      time  day  month  \
# 0                          12          4 2023-11-08  08:12:03    8     11
# 1                          12          3 2023-11-08  08:12:03    8     11
# 2                           8  satisfied 2024-03-18  10:08:57   18      3
# 3                           8   required 2024-03-18  10:08:58   18      3
# 4                           5  satisfied 2024-03-18  13:54:53   18      3
# ...                       ...        ...        ...       ...  ...    ...
# 463892                      2  satisfied 2025-01-23  10:07:21   23      1
# 463893                      2  satisfied 2025-01-23  10:10:50   23      1
# 463894                      1   required 2025-01-23  10:14:00   23      1
# 463895                     13   required 2025-01-23  10:14:00   23      1
# 463896                      2   required 2025-01-23  10:14:01   23      1
#
#         year  hours  minutes  seconds
# 0       2023      8       12        3
# 1       2023      8       12        3
# 2       2024     10        8       57
# 3       2024     10        8       58
# 4       2024     13       54       53
# ...      ...    ...      ...      ...
# 463892  2025     10        7       21
# 463893  2025     10       10       50
# 463894  2025     10       14        0
# 463895  2025     10       14        0
# 463896  2025     10       14        1
#
# [463897 rows x 13 columns]

# %% [markdown]
# ## Remove empty rows

# %%
# Remove all rows with any empty (NaN) cells
processed = processed.dropna()

processed

df = processed

# %% [markdown]
# ## Change room values

# %%
unique_rooms = df['room'].unique()

print(unique_rooms)
# Out:
# ['חדר הלם' 'מיון קורונה ב`' 'A104' 'T5' 'T6' 'T2' 'T3' 'T4' 'A113' 'A111'
#  'חדר גבס 5' 'A117' 'A109' 'A108' 'A107' 'A106' 'A112' 'A114' 'A115'
#  'A116' 'A101' 'A102' 'A103' 'A105' 'A110' 'C309' 'C310' 'C303' 'C306'
#  'C307' 'C301' 'C315' 'C304' 'C316' 'B204' 'B210' 'B206' 'B203' 'B202'
#  'B214' 'C302' 'B201' 'C320' '431' 'טריאז 3' 'טריאז 2' 'דמים' 'T1' 'B217'
#  'B209' 'טריאז 1' '404-405' '403' 'B205' 'B216' 'C312' 'המתנה כללי'
#  '404/405' '418' 'חדר ספטי 9' 'המתנה פנימי' 'חדר בידוד 1' 'חדר טיפולים 7'
#  '117' 'ממתין להחלטה' 'עיניים' '9' '21' '18' '39' 'ממתין למכתב שחרור'
#  'ממתין ליעוץ' '50' '2' '23' '30' '7' '28' '16' '12' 'ממתין לבדיקות מעבדה'
#  '15' '3' '17' 'חדר בידוד' '8' '19' '6' '29' '4' '13' '14' 'צילום' ' '
#  'CT' 'B213' '215' '24' 'B215' 'אורולוג' '201' 'ממתין לאשפוז' 'C318' '415'
#  'C321' '1' '27' '25' 'רופא מהלכים 4' '10' '26' '22' 'ממתין לתשובת הדמיה'
#  '11' 'א.א.ג.' 'חדר גבס' 'נשים' '101' 'רופא מהלכים 3' '63' 'US'
#  'רופא מהלכים 1' '61' '20' '62' '5' '55' '109' '203' '208' '214' 'B208'
#  'C308' 'א.ק.ג' '202' '310' '427/428' '314' 'DR1' 'C314' '429/430'
#  'חדר גבס 4' '425-426' '102' '309' 'חדר גבס 2' 'DR2' '301' 'חדר הלם 5'
#  '209' '319' '216' '60' 'מיון פנימי' '57' 'א.א.ג' 'חדר תפירה' '56'
#  'ממתין להדמיה' 'B212' 'B211' '59' 'נוירולוג' '58' 'C319' 'דיאליזה'
#  '39-נשימתי' '105' '302' 'חדר המתנה' '411' '429-430' '116' '303' '401'
#  'חדר צוות' 'C311' '114' '217' '110' '306' 'חדר הלם 4' 'C305' '213'
#  'משרד קבלה' 'חדר סמינרים' '315' '307' '113' '104' '107' '212' '204'
#  '427-428' '304' '112' '205' '305' '311' '103' 'C313' '211' '115'
#  'חדר טיפולים 6' '111' 'C317' '318' '108' '308' '210' '207' '316' 'B207'
#  '106' '317' '206' '417' '321' '320' '313' '312' '419/420' 'בידוד 2' '402'
#  'חדר גבס 1' 'חדר בידוד 2' '409' '425' '424' '426' '413' '406' '414' '412'
#  '421' '410' '423' 'בידוד 1' 'חדר טיפולים 8' 'חדר הלם 2' '408' '407'
#  'חדר הלם 3' 'חדם הלם 1' '419-420' 'חדר תרופות' 'המתנה אורטופדי'
#  'ציוד רפואי' '416' 'ייעוץ' 'הדמיה' 'חדר רופא 12' 'חדר רופא 14'
#  'חדר רופא 13' 'חדר רופא 15' 'חדר תפירה 6' 'חדר רופא 16' 'מסחן שוכבים'
#  'חדר תפירה 7']

# %%
# Create a dictionary mapping non-numeric values to unique integers
room_mapping = {value: i for i, value in enumerate(unique_rooms, 1)}

# Opt into the future behavior
pd.set_option('future.no_silent_downcasting', True)

df.loc[:, 'room'] = df['room'].replace(room_mapping)

# %%
df
# Out:
#                      department room    requirement  requirements_category  \
# 0       מיון כירורגיה - מ.הלכים    1     רמת דחיפות                     12
# 1                    מיון פנימי    2     רמת דחיפות                     12
# 2                             A    3   ניקיון تنظيف                      8
# 3                             A    3   ניקיון تنظيف                      8
# 4                    טראומה חדש    4  כח עזר - אוכל                      5
# ...                         ...  ...            ...                    ...
# 463892                        A   18     בדיקת רופא                      2
# 463893                        C   34     בדיקת רופא                      2
# 463894                        A    3       בדיקת דם                      1
# 463895                        A    3           תפוס                     13
# 463896                        A    3     בדיקת רופא                      2
#
#            status       date      time  day  month  year  hours  minutes  \
# 0               4 2023-11-08  08:12:03    8     11  2023      8       12
# 1               3 2023-11-08  08:12:03    8     11  2023      8       12
# 2       satisfied 2024-03-18  10:08:57   18      3  2024     10        8
# 3        required 2024-03-18  10:08:58   18      3  2024     10        8
# 4       satisfied 2024-03-18  13:54:53   18      3  2024     13       54
# ...           ...        ...       ...  ...    ...   ...    ...      ...
# 463892  satisfied 2025-01-23  10:07:21   23      1  2025     10        7
# 463893  satisfied 2025-01-23  10:10:50   23      1  2025     10       10
# 463894   required 2025-01-23  10:14:00   23      1  2025     10       14
# 463895   required 2025-01-23  10:14:00   23      1  2025     10       14
# 463896   required 2025-01-23  10:14:01   23      1  2025     10       14
#
#         seconds
# 0             3
# 1             3
# 2            57
# 3            58
# 4            53
# ...         ...
# 463892       21
# 463893       50
# 463894        0
# 463895        0
# 463896        1
#
# [463296 rows x 13 columns]

# %%
df.loc[:, 'room'] = df['room'].astype(int)

# %%
print(df.dtypes)
# Out:
# department                       object
# room                             object
# requirement                      object
# requirements_category             int64
# status                           object
# date                     datetime64[ns]
# time                             object
# day                               int32
# month                             int32
# year                              int32
# hours                             int64
# minutes                           int64
# seconds                           int64
# dtype: object

# %%
non_numeric_values = df['room'][df['room'].apply(lambda x: not isinstance(x, (int, float)))].unique()

# Print the non-numeric values
print(non_numeric_values)

nan_values = df['room'][df['room'].isna()]

# Print the rows with NaN values
print(nan_values)
# Out:
# []
# Series([], Name: room, dtype: object)

# %%
df
# Out:
#                      department room    requirement  requirements_category  \
# 0       מיון כירורגיה - מ.הלכים    1     רמת דחיפות                     12
# 1                    מיון פנימי    2     רמת דחיפות                     12
# 2                             A    3   ניקיון تنظيف                      8
# 3                             A    3   ניקיון تنظيف                      8
# 4                    טראומה חדש    4  כח עזר - אוכל                      5
# ...                         ...  ...            ...                    ...
# 463892                        A   18     בדיקת רופא                      2
# 463893                        C   34     בדיקת רופא                      2
# 463894                        A    3       בדיקת דם                      1
# 463895                        A    3           תפוס                     13
# 463896                        A    3     בדיקת רופא                      2
#
#            status       date      time  day  month  year  hours  minutes  \
# 0               4 2023-11-08  08:12:03    8     11  2023      8       12
# 1               3 2023-11-08  08:12:03    8     11  2023      8       12
# 2       satisfied 2024-03-18  10:08:57   18      3  2024     10        8
# 3        required 2024-03-18  10:08:58   18      3  2024     10        8
# 4       satisfied 2024-03-18  13:54:53   18      3  2024     13       54
# ...           ...        ...       ...  ...    ...   ...    ...      ...
# 463892  satisfied 2025-01-23  10:07:21   23      1  2025     10        7
# 463893  satisfied 2025-01-23  10:10:50   23      1  2025     10       10
# 463894   required 2025-01-23  10:14:00   23      1  2025     10       14
# 463895   required 2025-01-23  10:14:00   23      1  2025     10       14
# 463896   required 2025-01-23  10:14:01   23      1  2025     10       14
#
#         seconds
# 0             3
# 1             3
# 2            57
# 3            58
# 4            53
# ...         ...
# 463892       21
# 463893       50
# 463894        0
# 463895        0
# 463896        1
#
# [463296 rows x 13 columns]

# %%
df['requirement'].unique()
# Out:
# array(['רמת דחיפות', 'ניקיון تنظيف', 'כח עזר - אוכל', 'כח עזר - שונות',
#        'צר"פ', 'כביסה', 'כח עזר - סיוע למטופל', 'תפוס', 'בדיקת דם',
#        'בדיקת אק"ג', 'יעוץ', 'נקיון - החלפת פרגוד', 'נקיון - בידוד',
#        'בדיקת רופא'], dtype=object)

# %%
# Label mapping
category_mapping = dict(zip(encoder.classes_, encoder.transform(encoder.classes_)))
print("\nCategory to Label Mapping:")
print(category_mapping)
# Out:
# Category to Label Mapping:
# {'בדיקת אק"ג': np.int64(0), 'בדיקת דם': np.int64(1), 'בדיקת רופא': np.int64(2), 'יעוץ': np.int64(3), 'כביסה': np.int64(4), 'כח עזר - אוכל': np.int64(5), 'כח עזר - סיוע למטופל': np.int64(6), 'כח עזר - שונות': np.int64(7), 'ניקיון تنظيف': np.int64(8), 'נקיון - בידוד': np.int64(9), 'נקיון - החלפת פרגוד': np.int64(10), 'צר"פ': np.int64(11), 'רמת דחיפות': np.int64(12), 'תפוס': np.int64(13)}

# %%
# Move new column next to requirements column
cols = list(df.columns)
cols.remove('requirements_category')  # Remove column 'C'
cols.insert(3, 'requirements_category')  # Insert column 'C' after 'A'
df = df[cols]
df
# Out:
#                      department room    requirement  requirements_category  \
# 0       מיון כירורגיה - מ.הלכים    1     רמת דחיפות                     12
# 1                    מיון פנימי    2     רמת דחיפות                     12
# 2                             A    3   ניקיון تنظيف                      8
# 3                             A    3   ניקיון تنظيف                      8
# 4                    טראומה חדש    4  כח עזר - אוכל                      5
# ...                         ...  ...            ...                    ...
# 463892                        A   18     בדיקת רופא                      2
# 463893                        C   34     בדיקת רופא                      2
# 463894                        A    3       בדיקת דם                      1
# 463895                        A    3           תפוס                     13
# 463896                        A    3     בדיקת רופא                      2
#
#            status       date      time  day  month  year  hours  minutes  \
# 0               4 2023-11-08  08:12:03    8     11  2023      8       12
# 1               3 2023-11-08  08:12:03    8     11  2023      8       12
# 2       satisfied 2024-03-18  10:08:57   18      3  2024     10        8
# 3        required 2024-03-18  10:08:58   18      3  2024     10        8
# 4       satisfied 2024-03-18  13:54:53   18      3  2024     13       54
# ...           ...        ...       ...  ...    ...   ...    ...      ...
# 463892  satisfied 2025-01-23  10:07:21   23      1  2025     10        7
# 463893  satisfied 2025-01-23  10:10:50   23      1  2025     10       10
# 463894   required 2025-01-23  10:14:00   23      1  2025     10       14
# 463895   required 2025-01-23  10:14:00   23      1  2025     10       14
# 463896   required 2025-01-23  10:14:01   23      1  2025     10       14
#
#         seconds
# 0             3
# 1             3
# 2            57
# 3            58
# 4            53
# ...         ...
# 463892       21
# 463893       50
# 463894        0
# 463895        0
# 463896        1
#
# [463296 rows x 13 columns]

# %%
# התחלה לפי הכללים: A=1, B/טראומה=2, C=3
# יצירת מילון לפי חוקי המיפוי
custom_mapping = {}
current_value = 1

# רשימת מחלקות ייחודיות
unique_departments = df['department'].dropna().unique()
for dept in unique_departments:
    dept_lower = dept.lower()
    if dept_lower == 'a':
        custom_mapping[dept] = 1
    elif 'b' in dept_lower or 'טראומה' in dept_lower:
        custom_mapping[dept] = 2
    elif 'c' in dept_lower:
        custom_mapping[dept] = 3

# מיפוי השאר עם ערכים עוקבים
used_values = set(custom_mapping.values())
for dept in unique_departments:
    if dept not in custom_mapping:
        while current_value in used_values:
            current_value += 1
        custom_mapping[dept] = current_value
        used_values.add(current_value)

# הוספת עמודת מיפוי חדשה
df['department_numeric'] = df['department'].map(custom_mapping)

# %%
df
# Out:
#                      department room    requirement  requirements_category  \
# 0       מיון כירורגיה - מ.הלכים    1     רמת דחיפות                     12
# 1                    מיון פנימי    2     רמת דחיפות                     12
# 2                             A    3   ניקיון تنظيف                      8
# 3                             A    3   ניקיון تنظيف                      8
# 4                    טראומה חדש    4  כח עזר - אוכל                      5
# ...                         ...  ...            ...                    ...
# 463892                        A   18     בדיקת רופא                      2
# 463893                        C   34     בדיקת רופא                      2
# 463894                        A    3       בדיקת דם                      1
# 463895                        A    3           תפוס                     13
# 463896                        A    3     בדיקת רופא                      2
#
#            status       date      time  day  month  year  hours  minutes  \
# 0               4 2023-11-08  08:12:03    8     11  2023      8       12
# 1               3 2023-11-08  08:12:03    8     11  2023      8       12
# 2       satisfied 2024-03-18  10:08:57   18      3  2024     10        8
# 3        required 2024-03-18  10:08:58   18      3  2024     10        8
# 4       satisfied 2024-03-18  13:54:53   18      3  2024     13       54
# ...           ...        ...       ...  ...    ...   ...    ...      ...
# 463892  satisfied 2025-01-23  10:07:21   23      1  2025     10        7
# 463893  satisfied 2025-01-23  10:10:50   23      1  2025     10       10
# 463894   required 2025-01-23  10:14:00   23      1  2025     10       14
# 463895   required 2025-01-23  10:14:00   23      1  2025     10       14
# 463896   required 2025-01-23  10:14:01   23      1  2025     10       14
#
#         seconds  department_numeric
# 0             3                   4
# 1             3                   5
# 2            57                   1
# 3            58                   1
# 4            53                   2
# ...         ...                 ...
# 463892       21                   1
# 463893       50                   3
# 463894        0                   1
# 463895        0                   1
# 463896        1                   1
#
# [463296 rows x 14 columns]

# %%
# Function to check if value is numeric
def is_numeric(val):
    try:
        float(val)
        return True
    except:
        return False

# Get unique values
unique_statuses = df['status'].dropna().unique()
# Get unique values
unique_statuses = df['status'].dropna().unique()

# Separate numeric and non-numeric
non_numeric_statuses = [s for s in unique_statuses if not is_numeric(s)]
existing_numeric_values = [float(s) for s in unique_statuses if is_numeric(s)]
start_value = int(max(existing_numeric_values, default=0)) + 1

# Map non-numeric values
status_mapping = {status: i for i, status in enumerate(non_numeric_statuses, start=start_value)}

# Apply the mapping
df['status_numeric'] = df['status'].apply(lambda x: float(x) if is_numeric(x) else status_mapping.get(x))

# %%
df
# Out:
#                      department room    requirement  requirements_category  \
# 0       מיון כירורגיה - מ.הלכים    1     רמת דחיפות                     12
# 1                    מיון פנימי    2     רמת דחיפות                     12
# 2                             A    3   ניקיון تنظيف                      8
# 3                             A    3   ניקיון تنظيف                      8
# 4                    טראומה חדש    4  כח עזר - אוכל                      5
# ...                         ...  ...            ...                    ...
# 463892                        A   18     בדיקת רופא                      2
# 463893                        C   34     בדיקת רופא                      2
# 463894                        A    3       בדיקת דם                      1
# 463895                        A    3           תפוס                     13
# 463896                        A    3     בדיקת רופא                      2
#
#            status       date      time  day  month  year  hours  minutes  \
# 0               4 2023-11-08  08:12:03    8     11  2023      8       12
# 1               3 2023-11-08  08:12:03    8     11  2023      8       12
# 2       satisfied 2024-03-18  10:08:57   18      3  2024     10        8
# 3        required 2024-03-18  10:08:58   18      3  2024     10        8
# 4       satisfied 2024-03-18  13:54:53   18      3  2024     13       54
# ...           ...        ...       ...  ...    ...   ...    ...      ...
# 463892  satisfied 2025-01-23  10:07:21   23      1  2025     10        7
# 463893  satisfied 2025-01-23  10:10:50   23      1  2025     10       10
# 463894   required 2025-01-23  10:14:00   23      1  2025     10       14
# 463895   required 2025-01-23  10:14:00   23      1  2025     10       14
# 463896   required 2025-01-23  10:14:01   23      1  2025     10       14
#
#         seconds  department_numeric  status_numeric
# 0             3                   4             4.0
# 1             3                   5             3.0
# 2            57                   1             6.0
# 3            58                   1             7.0
# 4            53                   2             6.0
# ...         ...                 ...             ...
# 463892       21                   1             6.0
# 463893       50                   3             6.0
# 463894        0                   1             7.0
# 463895        0                   1             7.0
# 463896        1                   1             7.0
#
# [463296 rows x 15 columns]

# %%
# Set up the plotting area
plt.figure(figsize=(20, 6))

# Plot Histogram
sns.histplot(df['status_numeric'], kde=False, bins=10, color='blue', edgecolor='black')

# Add title and labels
plt.title('Distribution of Numeric Status')
plt.xlabel('Status Numeric')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %%
# show absolute correlation between features in a heatmap
def show_heatmap(data):
  plt.figure(figsize=(18,10))
  cor = np.abs(data.corr())
  sns.heatmap(cor, annot=True, cmap=plt.cm.Purples, vmin=-1, vmax=1)
    
  plt.show()

# %%
numeric_columns = df.select_dtypes(include=['int','float'])
numeric_columns
# Out:
#         requirements_category  day  month  year  hours  minutes  seconds  \
# 0                          12    8     11  2023      8       12        3
# 1                          12    8     11  2023      8       12        3
# 2                           8   18      3  2024     10        8       57
# 3                           8   18      3  2024     10        8       58
# 4                           5   18      3  2024     13       54       53
# ...                       ...  ...    ...   ...    ...      ...      ...
# 463892                      2   23      1  2025     10        7       21
# 463893                      2   23      1  2025     10       10       50
# 463894                      1   23      1  2025     10       14        0
# 463895                     13   23      1  2025     10       14        0
# 463896                      2   23      1  2025     10       14        1
#
#         department_numeric  status_numeric
# 0                        4             4.0
# 1                        5             3.0
# 2                        1             6.0
# 3                        1             7.0
# 4                        2             6.0
# ...                    ...             ...
# 463892                   1             6.0
# 463893                   3             6.0
# 463894                   1             7.0
# 463895                   1             7.0
# 463896                   1             7.0
#
# [463296 rows x 9 columns]

# %%
show_heatmap(numeric_columns)

# %%
# Initialize the LabelEncoder
le = LabelEncoder()

# Encode the 'Department' column
df['department_numeric'] = le.fit_transform(df['department'])

print(df)
# Out:
#                      department room    requirement  requirements_category  \
# 0       מיון כירורגיה - מ.הלכים    1     רמת דחיפות                     12
# 1                    מיון פנימי    2     רמת דחיפות                     12
# 2                             A    3   ניקיון تنظيف                      8
# 3                             A    3   ניקיון تنظيف                      8
# 4                    טראומה חדש    4  כח עזר - אוכל                      5
# ...                         ...  ...            ...                    ...
# 463892                        A   18     בדיקת רופא                      2
# 463893                        C   34     בדיקת רופא                      2
# 463894                        A    3       בדיקת דם                      1
# 463895                        A    3           תפוס                     13
# 463896                        A    3     בדיקת רופא                      2
#
#            status       date      time  day  month  year  hours  minutes  \
# 0               4 2023-11-08  08:12:03    8     11  2023      8       12
# 1               3 2023-11-08  08:12:03    8     11  2023      8       12
# 2       satisfied 2024-03-18  10:08:57   18      3  2024     10        8
# 3        required 2024-03-18  10:08:58   18      3  2024     10        8
# 4       satisfied 2024-03-18  13:54:53   18      3  2024     13       54
# ...           ...        ...       ...  ...    ...   ...    ...      ...
# 463892  satisfied 2025-01-23  10:07:21   23      1  2025     10        7
# 463893  satisfied 2025-01-23  10:10:50   23      1  2025     10       10
# 463894   required 2025-01-23  10:14:00   23      1  2025     10       14
# 463895   required 2025-01-23  10:14:00   23      1  2025     10       14
# 463896   required 2025-01-23  10:14:01   23      1  2025     10       14
#
#         seconds  department_numeric  status_numeric
# 0             3                  20             4.0
# 1             3                  23             3.0
# 2            57                   0             6.0
# 3            58                   0             7.0
# 4            53                  13             6.0
# ...         ...                 ...             ...
# 463892       21                   0             6.0
# 463893       50                   4             6.0
# 463894        0                   0             7.0
# 463895        0                   0             7.0
# 463896        1                   0             7.0
#
# [463296 rows x 15 columns]

# %%
# Count the occurrences of each department
department_counts = df['department_numeric'].value_counts()

# Create a barplot with counts
plt.figure(figsize=(8, 6))
sns.barplot(x=department_counts.index, y=department_counts.values, palette='Set2')

# Add title and labels
plt.title('Department Frequency Distribution')
plt.xlabel('Department')
plt.ylabel('Frequency')

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_900080/1961235143.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=department_counts.index, y=department_counts.values, palette='Set2')

# %%
filtered_df_sat = df[df['status']=="satisfied"]
filtered_df_req = df[df['status']=="required"]

# %%
# Create a countplot to show the frequency of departments that satisfy the condition
plt.figure(figsize=(8, 6))
sns.countplot(x='department_numeric', data=filtered_df_sat, palette='Set2')

# Add title and labels
plt.title('Department Frequency Distribution (Status satisfied)')
plt.xlabel('Department')
plt.ylabel('Frequency')

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_900080/315269669.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='department_numeric', data=filtered_df, palette='Set2')

# %%
# Create a countplot to show the frequency of departments that satisfy the condition
plt.figure(figsize=(8, 6))
sns.countplot(x='department_numeric', data=filtered_df_sat, palette='Set2')

# Add title and labels
plt.title('Department Frequency Distribution (Status satisfied)')
plt.xlabel('Department')
plt.ylabel('Frequency')

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_900080/315269669.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='department_numeric', data=filtered_df, palette='Set2')

# %%
# Display the mapping of categories to encoded values
print("Label encoding mapping:")
for i, category in enumerate(le.classes_):
    print(f"{category}: {i}")
# Out:
# Label encoding mapping:
# A: 0
# A מלרד אגף: 1
# B: 2
# B מלרד אגף: 3
# C: 4
# C מלרד אגף: 5
# D מלרד מהלכים: 6
# דימות: 7
# המחלקה לרפואה דחופה: 8
# המחלקה לרפואה דחופה - לא פעיל: 9
# חדר הלם: 10
# חדר סמינרים: 11
# חדר צוות: 12
# טראומה חדש: 13
# טריאז' מיון חדש: 14
# מחסן שוכבים: 15
# מיון אורתופדי: 16
# מיון אורתופדי - לא פעיל: 17
# מיון כירורגי: 18
# מיון כירורגי - לא פעיל: 19
# מיון כירורגיה - מ.הלכים: 20
# מיון מהלכים: 21
# מיון מהלכים - לא פעיל: 22
# מיון פנימי: 23
# מיון פנימי - לא פעיל: 24
# מלר"ד אגף מהלכים: 25
# מלרד טראומה: 26
# מלרד טראומה בנין 16: 27
# מלרד מהלכים: 28
# מלרד מהלכים בנין 16: 29
# משרד קבלה: 30

# %%
# Create a countplot to show the frequency of departments that satisfy the condition
plt.figure(figsize=(8, 6))
sns.countplot(x='department_numeric', data=filtered_df_req, palette='Set2')

# Add title and labels
plt.title('Department Frequency Distribution (Status required)')
plt.xlabel('Department')
plt.ylabel('Frequency')

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_900080/3503956932.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='department_numeric', data=filtered_df_req, palette='Set2')
